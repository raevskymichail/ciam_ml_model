# %% [markdown]
# # The stacked model by blade zones

# %%
import pandas as pd
import numpy as np
import os
import re

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, GroupKFold, train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils import resample
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

from math import sqrt

from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import xgboost as xgb

import pickle

matplotlib.rcParams['axes.labelsize'] = 14
# %matplotlib inline

# %% [markdown]
# __Notice:__ In `sklearn` Polynomial Regression is defined indirectly.
# First, you have to obtain polynomial features to linearaze data and then fit with vanilla `LinearRegression`
# ```python
# poly_reg = PolynomialFeatures(degree=3)
# X_poly = poly_reg.fit_transform(X_train)
# pol_reg = LinearRegression()
# pol_reg.fit(X_poly, y_train)
# ```

# %%
from surrogate_model import *

# %%
# Import the datasets
data_zone1 = pd.read_csv('./datasets/by_zone/Results_3079.csv')
data_zone2 = pd.read_csv('./datasets/by_zone/Results_32434.csv')
data_zone3 = pd.read_csv('./datasets/by_zone/Results_36302.csv')
data_zone4 = pd.read_csv('./datasets/by_zone/Results_37227.csv')
data_zone5 = pd.read_csv('./datasets/by_zone/Results_94936.csv')

# %%
# Initialize models for each zone
surrogate_blade_zone1 = surrogate_model(data_zone1)
surrogate_blade_zone2 = surrogate_model(data_zone2)
surrogate_blade_zone3 = surrogate_model(data_zone3)
surrogate_blade_zone4 = surrogate_model(data_zone4)
surrogate_blade_zone5 = surrogate_model(data_zone5)

# %%
surrogate_blade_zone1.train(data_size_multipl_by=100)
pickle.dump(surrogate_blade_zone1, open('surrogate_blade_zone1.pkl', 'wb'))

# %%
surrogate_blade_zone2.train(data_size_multipl_by=100)
pickle.dump(surrogate_blade_zone2, open('surrogate_blade_zone2.pkl', 'wb'))

# %%
surrogate_blade_zone3.train(data_size_multipl_by=100)
pickle.dump(surrogate_blade_zone3, open('surrogate_blade_zone3.pkl', 'wb'))

# %%
surrogate_blade_zone4.train(data_size_multipl_by=100)
pickle.dump(surrogate_blade_zone4, open('surrogate_blade_zone4.pkl', 'wb'))

# %%
surrogate_blade_zone5.train(data_size_multipl_by=100)
pickle.dump(surrogate_blade_zone5, open('surrogate_blade_zone5.pkl', 'wb'))

# %% [markdown]
# ## Visualization

# %%
babel_weather = pd.read_csv('../../Desktop/babel_2000_2020.csv', sep=";")

# %%
babel_weather.index = pd.to_datetime(babel_weather.loc[:, ['Year', 'Month', 'Day']])

# %%
babel_weather.drop(columns=['Year', 'Month', 'Day', 'Hour', 'Minute'], inplace=True)

# %%
df = babel_weather['2015-01-01':'2020-01-01']

# %%
df['Norilsk_Temp_avg'] = df['Tmin'] -10
df['Moscow_Temp_avg'] = df['Tmax']

# %%
df.loc[:, ['Norilsk_Temp_avg', 'Moscow_Temp_avg']].plot()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Median air temperarute', y=1.01, fontsize=19, fontweight='bold')
ax.plot(df.loc[:, ['Norilsk_Temp_avg', 'Moscow_Temp_avg']])
# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
ax.set_ylabel('Temperature (°C)', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend(['Norilsk', 'Moscow area'])
ax.grid()
fig.savefig('exploit_conds_temps.png')
fig.show()

# %%
df['Moscow'] = round(df['Moscow_Temp_avg'])
df['Norilsk'] = round(df['Norilsk_Temp_avg'])

df['date'] = df.index

sm_data_msk = data_zone1[data_zone1['Ta'].isin(df['Moscow'])]
sm_data_msk = sm_data_msk.merge(df.loc[:,['Moscow', 'date']], left_on='Ta', right_on='Moscow')
sm_data_msk = sm_data_msk.sort_values(by='date')
sm_data_msk.index = sm_data_msk['date']

sm_data_nrsk = data_zone1[data_zone1['Ta'].isin(df['Norilsk'])]
sm_data_nrsk = sm_data_nrsk.merge(df.loc[:,['Norilsk', 'date']], left_on='Ta', right_on='Norilsk')
sm_data_nrsk = sm_data_nrsk.sort_values(by='date')
sm_data_nrsk.index = sm_data_nrsk['date']

# %%
sm_data_nrsk['Damage'].cumsum()
# Out:
# date
# 2015-01-01    1.827539e-14
# 2015-01-02    4.690695e-14
# 2015-01-03    9.148219e-14
# 2015-01-04    1.974875e-13
# 2015-01-05    2.261191e-13
#                   ...
# 2019-12-28    4.177981e-08
# 2019-12-29    4.177984e-08
# 2019-12-30    4.177988e-08
# 2019-12-31    4.177999e-08
# 2020-01-01    4.178003e-08
# Name: Damage, Length: 1824, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_nrsk.index, sm_data_nrsk['Damage'].cumsum(), linewidth=2.5)
ax.step(sm_data_msk.index, sm_data_msk['Damage'].cumsum(), linewidth=2.5)
# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
ax.set_yscale("log")
# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend(['Norilsk', 'Moscow area'])
ax.grid()
# fig.savefig('exploit_conds_damage.png')
fig.show()

# %%
sm_data_msk.Damage.plot()

# %%
sm_data_nrsk.Damage.plot()

# %% [markdown]
# __Moscow - Kerch__ temperatures

# %%
msk_temp = pd.read_csv('../Moscow.csv')
krd_temp = pd.read_csv('../Kerch.csv')

msk_temp.index = pd.to_datetime(msk_temp['DATE'])
krd_temp.index = pd.to_datetime(krd_temp['DATE'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Median air temperarute', y=1.01, fontsize=19, fontweight='bold')
ax.plot(msk_temp['TAVG'], label='Moscow area')
ax.plot(krd_temp['TAVG'], label='Krasnodar area')

# line1.set_legend('Krasnodar area')
# line2.set_legend('Moscow area')

# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
ax.set_ylabel('Temperature (°C)', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
# ax.legend((line1, line2), ('Krasnodar area', 'Moscow area'))
ax.legend()
ax.grid()
fig.savefig('exploit_conds_temps.png')
fig.show()

# %%
msk_temp['TAVG'][msk_temp['TAVG'] < -17] = -15

# %%
msk_temp['2018-02-01':'2018-06-01']['TAVG'].plot()

# %%
df = pd.DataFrame()

df['Moscow'] = round(msk_temp['TAVG'])
df['Krasnodar'] = round(krd_temp['TAVG'])

df['date'] = msk_temp.index

sm_data_msk = data_zone5[data_zone5['Ta'].isin(df['Moscow'])]
sm_data_msk = sm_data_msk.merge(df.loc[:,['Moscow', 'date']], left_on='Ta', right_on='Moscow')
sm_data_msk = sm_data_msk.sort_values(by='date')
sm_data_msk.index = sm_data_msk['date']

sm_data_krd = data_zone5[data_zone5['Ta'].isin(df['Krasnodar'])]
sm_data_krd = sm_data_krd.merge(df.loc[:,['Krasnodar', 'date']], left_on='Ta', right_on='Krasnodar')
sm_data_krd = sm_data_krd.sort_values(by='date')
sm_data_krd.index = sm_data_krd['date']

# %%
sm_data_krd_zone5 = sm_data_krd.copy()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_msk.index, sm_data_msk['Damage'].cumsum(), linewidth=2.5, label='Moscow area')
ax.step(sm_data_krd.index, sm_data_krd['Damage'].cumsum(), linewidth=2.5, label='Krasnodar area')
# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
# ax.set_yscale("log")
# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend()
ax.grid()
fig.savefig('exploit_conds_damage_zone1.png')
fig.show()

# %%
data_zone1 = pd.read_csv('./datasets/by_zone/Results_3079.csv')
data_zone2 = pd.read_csv('./datasets/by_zone/Results_32434.csv')
data_zone3 = pd.read_csv('./datasets/by_zone/Results_36302.csv')
data_zone4 = pd.read_csv('./datasets/by_zone/Results_37227.csv')
data_zone5 = pd.read_csv('./datasets/by_zone/Results_94936.csv')

# %%
data_zone5['Damage'].max() * 1825
# Out:
# 2.3157919732782593

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

linewidth = 2.5

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_msk_zone1.index, sm_data_msk_zone1['Damage'].cumsum(), linewidth=linewidth, label='Results_3079')
ax.step(sm_data_msk_zone2.index, sm_data_msk_zone2['Damage'].cumsum(), linewidth=linewidth, label='Results_32434')
ax.step(sm_data_msk_zone3.index, sm_data_msk_zone3['Damage'].cumsum(), linewidth=linewidth, label='Results_36302')
ax.step(sm_data_msk_zone4.index, sm_data_msk_zone4['Damage'].cumsum(), linewidth=linewidth, label='Results_37227')
ax.step(sm_data_msk_zone5.index, sm_data_msk_zone5['Damage'].cumsum(), linewidth=linewidth, label='Results_94936')


# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
# ax.set_yscale("log")
# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend()
ax.grid()
fig.savefig('exploit_conds_damage_all_zones.png')
fig.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

linewidth = 2.5

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_krd_zone1.index, sm_data_krd_zone1['Damage'].cumsum(), linewidth=linewidth, label='Results_3079')
ax.step(sm_data_krd_zone2.index, sm_data_krd_zone2['Damage'].cumsum(), linewidth=linewidth, label='Results_32434')
ax.step(sm_data_krd_zone3.index, sm_data_krd_zone3['Damage'].cumsum(), linewidth=linewidth, label='Results_36302')
ax.step(sm_data_krd_zone4.index, sm_data_krd_zone4['Damage'].cumsum(), linewidth=linewidth, label='Results_37227')
ax.step(sm_data_krd_zone5.index, sm_data_krd_zone5['Damage'].cumsum(), linewidth=linewidth, label='Results_94936')


# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
# ax.set_yscale("log")
# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend()
ax.grid()
# fig.savefig('exploit_conds_damage_all_zones.png')
fig.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_msk.index, sm_data_msk['Damage'].cumsum(), linewidth=2.5, label='Moscow area')
ax.step(sm_data_krd.index, sm_data_krd['Damage'].cumsum(), linewidth=2.5, label='Krasnodar area')
# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
ax.set_yscale("log")

# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage (log-scaled)', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend()
ax.grid()
fig.savefig('exploit_conds_damage_log_zone1.png')
fig.show()

# %% [markdown]
# ## Zone 5

# %%
df = pd.DataFrame()

df['Moscow'] = round(msk_temp['TAVG'])
df['Krasnodar'] = round(krd_temp['TAVG'])

df['date'] = msk_temp.index

sm_data_msk = data_zone5[data_zone5['Ta'].isin(df['Moscow'])]
sm_data_msk = sm_data_msk.merge(df.loc[:,['Moscow', 'date']], left_on='Ta', right_on='Moscow')
sm_data_msk = sm_data_msk.sort_values(by='date')
sm_data_msk.index = sm_data_msk['date']

sm_data_krd = data_zone5[data_zone5['Ta'].isin(df['Krasnodar'])]
sm_data_krd = sm_data_krd.merge(df.loc[:,['Krasnodar', 'date']], left_on='Ta', right_on='Krasnodar')
sm_data_krd = sm_data_krd.sort_values(by='date')
sm_data_krd.index = sm_data_krd['date']

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

ax = ax or plt.gca()

# ax.set_title('Blade damage', y=1.01, fontsize=19, fontweight='bold')
ax.step(sm_data_msk.index, sm_data_msk['Damage'].cumsum(), linewidth=2.5, label='Moscow area')
ax.step(sm_data_krd.index, sm_data_krd['Damage'].cumsum(), linewidth=2.5, label='Krasnodar area')
# ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')

# ax.text(text_x_pos, text_y_pos, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
# ax.set_yscale("log")
# ax.set_ylim(0, 0.0005, 0.000005)
ax.set_ylabel('Damage', fontsize = 15)
ax.set_xlabel('Date (Years)', fontsize = 15)
ax.legend()
ax.grid()
fig.savefig('exploit_conds_damage_zone5.png')
fig.show()

# %%
sm_data['sorterIndex'] = sm_data['Ta'].map(sorterIndex)

# %%
temp.head()
# Out:
# 2015-01-01     4.0
# 2015-01-02     7.0
# 2015-01-03    11.0
# 2015-01-04    10.0
# 2015-01-05     6.0
# Name: Moscow_Temp_avg, dtype: float64

# %%
sm_data.sort_values(['sorterIndex'], ascending=[True])
# Out:
#       Ta      Fuel        Tg       Tk          n        Damage  sorterIndex
# 54  37.0  1.301990  1136.324  385.872  11944.637  2.584409e-05          185
# 15  -2.0  1.054534   792.247  344.357  11117.599  1.357805e-12          736
# 17   0.0  1.066259   805.679  346.384  11162.985  3.088668e-12         1151
# 13  -4.0  1.042626   778.858  342.333  11071.653  5.876589e-13         1153
# 16  -1.0  1.060419   798.958  345.370  11140.356  2.051331e-12         1154
# 19   2.0  1.077802   819.154  348.413  11207.864  6.925656e-12         1481
# 18   1.0  1.072053   812.412  347.398  11185.491  4.633872e-12         1485
# 20   3.0  1.083657   826.052  349.491  11229.446  1.041366e-11         1490
# 50  33.0  1.276236  1089.426  383.463  11845.876  4.101722e-06         1664
# 52  35.0  1.289280  1113.363  384.573  11897.368  1.063234e-05         1665
# 53  36.0  1.295679  1124.845  385.226  11921.051  1.663155e-05         1666
# 49  32.0  1.269648  1077.253  382.964  11818.712  2.504992e-06         1667
# 51  34.0  1.282793  1101.540  383.987  11872.310  6.663173e-06         1681
# 47  30.0  1.256156  1054.219  381.530  11769.389  9.524993e-07         1698
# 46  29.0  1.249292  1043.813  380.443  11749.247  6.036298e-07         1702
# 48  31.0  1.262932  1065.082  382.454  11791.470  1.517101e-06         1703
# 42  25.0  1.220823  1002.041  376.048  11667.968  9.940180e-08         1715
# 44  27.0  1.235249  1022.952  378.246  11708.841  2.354143e-07         1717
# 45  28.0  1.242324  1033.391  379.349  11729.065  3.781086e-07         1719
# 41  24.0  1.213549   991.594  374.985  11647.063  6.097612e-08         1734
# 33  16.0  1.161238   921.131  364.833  11490.255  1.913476e-09         1743
# 43  26.0  1.228065  1012.497  377.135  11688.577  1.461143e-07         1747
# 40  23.0  1.207139   982.618  373.734  11627.822  3.977663e-08         1753
# 39  22.0  1.200711   973.767  372.463  11608.553  2.588963e-08         1756
# 36  19.0  1.181145   947.316  368.652  11549.964  7.034392e-09         1757
# 38  21.0  1.194221   964.914  371.195  11589.141  1.674859e-08         1759
# 37  20.0  1.187700   956.098  369.924  11569.613  1.079417e-08         1760
# 34  17.0  1.167918   929.836  366.106  11510.290  2.964323e-09         1765
# 35  18.0  1.174553   938.563  367.379  11530.193  4.575165e-09         1766
# 28  11.0  1.130427   881.939  358.656  11393.324  2.456663e-10         1786
# 22   5.0  1.095439   839.936  351.696  11272.080  2.337101e-11         1795
# 23   6.0  1.101295   846.897  352.816  11293.014  3.483955e-11         1806
# 31  14.0  1.147767   903.799  362.289  11449.821  7.881417e-10         1809
# 32  15.0  1.154512   912.450  363.559  11470.085  1.230053e-09         1812
# 30  13.0  1.142053   896.037  361.096  11431.296  5.251014e-10         1814
# 29  12.0  1.136238   889.000  359.865  11412.574  3.599612e-10         1818
# 27  10.0  1.124607   874.896  357.453  11373.864  1.671112e-10         1821
# 21   4.0  1.089562   832.989  350.588  11250.894  1.562291e-11         1823
# 25   8.0  1.112943   860.851  355.092  11334.127  7.665776e-11         1824
# 26   9.0  1.118760   867.857  356.258  11354.179  1.132676e-10         1825
# 24   7.0  1.107129   853.868  353.948  11313.696  5.176943e-11         1826

# %%
surrogate_blade_zone1 = pickle.load(open('surrogate_blade_zone1.pkl', 'rb'))
surrogate_blade_zone2 = pickle.load(open('surrogate_blade_zone2.pkl', 'rb'))
surrogate_blade_zone3 = pickle.load(open('surrogate_blade_zone3.pkl', 'rb'))
surrogate_blade_zone4 = pickle.load(open('surrogate_blade_zone4.pkl', 'rb'))
surrogate_blade_zone5 = pickle.load(open('surrogate_blade_zone5.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-86-856006d8ded4> in <module>
# ----> 1 surrogate_blade_zone1 = pickle.load(open('surrogate_blade_zone1.pkl', 'rb'))
#       2 surrogate_blade_zone2 = pickle.load(open('surrogate_blade_zone2.pkl', 'rb'))
#       3 surrogate_blade_zone3 = pickle.load(open('surrogate_blade_zone3.pkl', 'rb'))
#       4 surrogate_blade_zone4 = pickle.load(open('surrogate_blade_zone4.pkl', 'rb'))
#       5 surrogate_blade_zone5 = pickle.load(open('surrogate_blade_zone5.pkl', 'rb'))
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in __setstate__(self, state)
#     978             length = c_bst_ulong(len(buf))
#     979             ptr = (ctypes.c_char * len(buf)).from_buffer(buf)
# --> 980             _check_call(_LIB.XGBoosterLoadModelFromBuffer(handle, ptr, length))
#     981             state['handle'] = handle
#     982         self.__dict__.update(state)
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in _check_call(ret)
#     176     """
#     177     if ret != 0:
# --> 178         raise XGBoostError(_LIB.XGBGetLastError())
#     179
#     180
#
# XGBoostError: b'[13:20:28] C:\\Users\\Administrator\\Desktop\\xgboost\\src\\objective\\objective.cc:23: Unknown objective function reg:squarederror'

# %%
# Plot the surrogate model in 3D 
y_pred = t.predict_values(xtest)

n_dots=20

x = np.linspace(data_limits[0, 0], data_limits[0, 1], n_dots)
y = np.linspace(data_limits[1, 0], data_limits[1, 1], n_dots)

resSM = []
# varSM = []
for x0 in x:
    for x1 in y:
        resSM.append(t.predict_values(np.array([[x0,x1]])))
#         varSM.append(t.predict_variances(np.array([[x0,x1]])))
        
resSM = np.array(resSM)
resSM = resSM.reshape((n_dots, n_dots)).T
# varSM = np.array(varSM)
# varSM = varSM.reshape((n_dots, n_dots)).T                     
X,Y = np.meshgrid(x,y)


fig = plt.figure(figsize=(13, 8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, resSM, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False,alpha=0.5)

# %%
import ploly
import plotly.offline as py
import plotly.graph_objs as go

data = data_zone1.copy()

trace1 = go.Scatter3d(
    x=data.Ta,
    y=data.Fuel,
    z=data.Damage,

    mode='markers',
    marker=dict(
        size=1,
        color=data.Damage,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

data_trace1 = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data_trace1, layout=layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4b07ce42cfd9> in <module>()
#      28 )
#      29 fig = go.Figure(data=data_trace1, layout=layout)
# ---> 30 py.plot(fig)
#
# /home/mraevsky/miniconda3/lib/python3.7/site-packages/plotly/offline/offline.py in plot(figure_or_data, show_link, link_text, validate, output_type, include_plotlyjs, filename, auto_open, image, image_filename, image_width, image_height, config, include_mathjax, auto_play, animation_opts)
#     594             validate=validate,
#     595             animation_opts=animation_opts,
# --> 596             auto_open=auto_open,
#     597         )
#     598         return filename
#
# /home/mraevsky/miniconda3/lib/python3.7/site-packages/plotly/io/_html.py in write_html(fig, file, config, auto_play, include_plotlyjs, include_mathjax, post_script, full_html, animation_opts, validate, default_width, default_height, auto_open)
#     541     if file_is_str and full_html and auto_open:
#     542         url = "file://" + os.path.abspath(file)
# --> 543         webbrowser.open(url)
#
# /home/mraevsky/.pyenv/versions/3.7.3/lib/python3.7/webbrowser.py in open(url, new, autoraise)
#      76     for name in _tryorder:
#      77         browser = get(name)
# ---> 78         if browser.open(url, new, autoraise):
#      79             return True
#      80     return False
#
# /home/mraevsky/.pyenv/versions/3.7.3/lib/python3.7/webbrowser.py in open(self, url, new, autoraise)
#     162             else:
#     163                 p = subprocess.Popen(cmdline, close_fds=True)
# --> 164             return not p.wait()
#     165         except OSError:
#     166             return False
#
# /home/mraevsky/.pyenv/versions/3.7.3/lib/python3.7/subprocess.py in wait(self, timeout)
#     988             endtime = _time() + timeout
#     989         try:
# --> 990             return self._wait(timeout=timeout)
#     991         except KeyboardInterrupt:
#     992             # https://bugs.python.org/issue25942
#
# /home/mraevsky/.pyenv/versions/3.7.3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1622                         if self.returncode is not None:
#    1623                             break  # Another thread waited.
# -> 1624                         (pid, sts) = self._try_wait(0)
#    1625                         # Check the pid and loop as waitpid has been known to
#    1626                         # return 0 even without WNOHANG in odd situations.
#
# /home/mraevsky/.pyenv/versions/3.7.3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1580             """All callers to this function MUST hold self._waitpid_lock."""
#    1581             try:
# -> 1582                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1583             except ChildProcessError:
#    1584                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## Learn ML to obtain params mesh grid

# %%
data_features = a.data.loc[:, ['Tg', 'Tk', 'n']]
data_features = a.scaler_features.transform(data_features)
# Make inference
model1_preds = a.lightgbm_model.predict(data_features)
model2_preds = a.adaboost_model.predict(data_features)
model3_preds = a.polynom_reg_model.predict(data_features)
model4_preds = a.catboost_model.predict(data_features)

models_preds = pd.concat([pd.DataFrame(model1_preds), pd.DataFrame(model2_preds), 
                          pd.DataFrame(model3_preds), pd.DataFrame(model4_preds)], axis = 1)
models_preds.columns = ['lightgbm_model', 'adaboost', 'polynom_reg', 'catboost']

damage_pred_scaled = a.strong_model.predict(models_preds)
damage_pred_scaled = damage_pred_scaled.reshape(-1, 1)
damage_pred = a.scaler_target.inverse_transform(damage_pred_scaled)

# %%
# Basic EDA
sns.pairplot(data1)

# %% [markdown]
# Since most of the `damage` values are near 0 (usual working conditions), but we want a good accuracy for extreme values too, lets split the dataset into 2 groups:
# __working__ and __extreme conditions__, and will sample them equally with `resample` (bootstraping by groups)

# %%
# Define split variable
split_val = 0.1
data['groups'] = [1 if f > split_val else 0 for f in data.damage]

# %%
# Bootstraping by groups (equal sampling)
n_samples = data.shape[0] * 3
data_resampled = resample(data, n_samples = n_samples, stratify = data.groups)

# %%
# Normalization
scaler = MinMaxScaler()
scaler.fit(data_resampled)

pickle.dump(scaler, open('scaler.pkl', 'wb')) # save fitted scaler
# scaler = pickle.load(open('scaler.pkl', 'rb')) # load it back

data_scaled = scaler.transform(data_resampled)
data_scaled = pd.DataFrame(data_scaled, columns = data.columns)
data_scaled['groups'] = data_scaled['groups'].astype('int')

# %%
sns.pairplot(data_scaled)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_scaled.loc[:, ['Tg', 'Tk', 'n']], data_scaled['damage'], test_size=0.2, random_state=42)

# %%
# Define function for CV for "weak" models
def Stacking(model, train, y, test, n_fold, with_eval_set = False):
    folds = KFold(n_splits = n_fold, random_state = 42)
    test_pred = np.empty((0, 1), float)
    train_pred = np.empty((0, 1), float)
    for train_indices, val_indices in folds.split(train, y.values):
        x_train, x_val = train.iloc[train_indices], train.iloc[val_indices]
        y_train, y_val = y.iloc[train_indices], y.iloc[val_indices]

        if with_eval_set == False:
            model.fit(x_train, y_train)
        else:
            model.fit(X = x_train, y = y_train, eval_set = [(x_val, y_val)], verbose = 0)
            
        train_pred = np.append(train_pred, model.predict(x_val))
        
    test_pred = np.append(test_pred, model.predict(test))
    return pd.DataFrame(test_pred), pd.DataFrame(train_pred), model

# %%
# Define lightGBM model
model0 = LGBMRegressor(boosting_type = 'gbdt',
                       metric = 'rmse',
                       n_estimators = 1000,
                       num_boost_round = 1000,
                       early_stopping_rounds = 100,
                       # device = 'gpu',
                       n_jobs = -1,
                       random_state = 42,
                       verbose = -1,
                       verbose_eval = False)

# Create the random grid
model0_param_grid = {'learning_rate': [x for x in np.linspace(0.001, 0.05, num = 5)],
                     'max_depth': [int(x) for x in np.linspace(2, 8, num = 4)]}

model0_rs = RandomizedSearchCV(estimator = model0,
                               param_distributions = model0_param_grid,
                               n_iter=10, cv=3, verbose=0)

# %%
# # Define RandomForest model
# model0 = RandomForestRegressor(n_estimators = 100,
#                                bootstrap = True,
#                                oob_score = True,
#                                n_jobs = -1,
#                                random_state = 42)

# %%
# Define AdaBoost model
model1 = AdaBoostRegressor(base_estimator = RandomForestRegressor(),
                           loss = 'square',
                           n_estimators = 1000,
                           random_state = 42)

# Create the random grid
model1_param_grid = {'learning_rate': [x for x in np.linspace(0.001, 0.05, num = 5)],
                     'base_estimator__max_depth': [int(x) for x in np.linspace(2, 8, num = 4)]}

model1_rs = RandomizedSearchCV(estimator = model1,
                               param_distributions = model1_param_grid,
                               n_iter=10, cv=3, verbose=0)

# %%
# Define polynomial regression model
model2 = make_pipeline(PolynomialFeatures(),
                       LinearRegression(n_jobs = -1))

model2_param_grid = {'polynomialfeatures__degree': [2, 3, 4, 5]}

model2_rs = RandomizedSearchCV(estimator = model2,
                               param_distributions = model2_param_grid,
                               n_iter=10, cv=3, verbose=0)

# %%
# Define CatBoost model
model3 = CatBoostRegressor(loss_function='RMSE',
                           random_seed = 42,
                           task_type = 'GPU',
                           # boosting_type = 'Plain', # set if it exceeds RAM
                           # params for early stopping:
                           iterations = 1000,
                           od_type = 'Iter',
                           od_wait = 100,
                           silent = True)

# Create the random grid
model3_param_grid = {'learning_rate': [x for x in np.linspace(0.001, 0.05, num = 5)],
                     'depth': [int(x) for x in np.linspace(2, 8, num = 4)]}

model3_rs = RandomizedSearchCV(estimator = model3,
                               param_distributions = model3_param_grid,
                               n_iter=10, cv=3, verbose=0)

# %%
# Train "weak" models
kwargs = {'n_fold': 10, 'train': X_train, 'test': X_test, 'y': y_train}

test_pred0, train_pred0, lightgbm_model = Stacking(model = model0, with_eval_set = True, **kwargs)
# pickle.dump(lightgbm_model, open('lightgbm_model.pkl', 'wb'))

test_pred1, train_pred1, adaboost_model = Stacking(model = model1_rs, **kwargs)
# pickle.dump(adaboost_model, open('adaboost_model.pkl', 'wb'))

test_pred2, train_pred2, polynom_reg_model = Stacking(model = model2_rs, **kwargs)
# pickle.dump(polynom_reg_model, open('polynom_reg_model.pkl', 'wb'))

test_pred3, train_pred3, catboost_model = Stacking(model = model3_rs, with_eval_set = True, **kwargs)
# pickle.dump(catboost_model, open('catboost_model.pkl', 'wb'))
# Out:
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125
# Warning: less than 75% gpu memory available for training. Free: 6126.1875 Total: 11178.125

# %%
# Create "strong" model over "weak" predictions
train_preds = pd.concat([train_pred0, train_pred1, train_pred2, train_pred3], axis = 1)
test_preds = pd.concat([test_pred0, test_pred1, test_pred2, test_pred3], axis = 1)
train_preds.columns = ['lightgbm_model', 'adaboost', 'polynom_reg', 'catboost']
test_preds.columns = ['lightgbm_model', 'adaboost', 'polynom_reg', 'catboost']

strong_model = xgb.XGBRegressor(eval_metric = "rmse",
                                # min_child_weight=1.5,                                                                  
                                # reg_alpha=0.75,
                                # reg_lambda=0.45,
                                objective='reg:squarederror',
                                n_estimators = 1000,
                                num_boost_round = 1000,
                                early_stopping_rounds = 100,
                                # max_depth = 2,
                                # num_leaves = 4,
                                eval_set = [(X_test, y_test)],
                                kvargs = {'tree_method':'gpu_hist'}, # enable GPU
                                seed = 42)

# Create the random grid
strong_model_param_grid = {'colsample_bytree': [0.4, 0.6, 0.8],
                           'reg_lambda': [0.01, 0.5, 1],
                           'learning_rate': [x for x in np.linspace(0.001, 0.05, num = 5)],
                           'max_depth': [int(x) for x in np.linspace(2, 8, num = 4)],
                           'num_leaves': [20, 40, 60, 80]}


strong_model = RandomizedSearchCV(estimator = strong_model,
                                  param_distributions = strong_model_param_grid,
                                  n_iter=100, cv=3, verbose=0)

strong_model.fit(train_preds, y_train)
# pickle.dump(strong_model, open('xgbr_strong_model.pkl', 'wb')) # save the fitted model

y_pred_test = strong_model.predict(test_preds)
print(f"RMSE score for stacked model: {sqrt(mean_squared_error(y_pred_test, y_test))}")
# Out:
# RMSE score for stacked model: 0.0009052603756906132

# %%
y_pred_test = strong_model.predict(test_preds)
print(f"RMSE score for stacked model: {sqrt(mean_squared_error(y_pred_test, y_test))}")
print(f"RMSE score for LightGBM model: {sqrt(mean_squared_error(test_pred0, y_test))}")
print(f"RMSE score for AdaBoost model: {sqrt(mean_squared_error(test_pred1, y_test))}")
print(f"RMSE score for polynimial regression: {sqrt(mean_squared_error(test_pred2, y_test))}")
print(f"RMSE score for CatBoost model: {sqrt(mean_squared_error(test_pred3, y_test))}")
# Out:
# RMSE score for stacked model: 0.0009052603756906132
# RMSE score for LightGBM model: 0.012030017903305844
# RMSE score for AdaBoost model: 0.0006192848001356577
# RMSE score for polynimial regression: 0.006991856066514724
# RMSE score for CatBoost model: 0.012473316848840706

# %%
y_pred_test = strong_model.predict(test_preds)
print(f"RMSE score for stacked model: {sqrt(mean_squared_error(y_pred_test, y_test))}")
print(f"RMSE score for LightGBM model: {sqrt(mean_squared_error(test_pred0, y_test))}")
print(f"RMSE score for AdaBoost model: {sqrt(mean_squared_error(test_pred1, y_test))}")
print(f"RMSE score for polynimial regression: {sqrt(mean_squared_error(test_pred2, y_test))}")
print(f"RMSE score for CatBoost model: {sqrt(mean_squared_error(test_pred3, y_test))}")
# Out:
# RMSE score for stacked model: 0.0006769867078193512
# RMSE score for LightGBM model: 0.0088917921494916
# RMSE score for AdaBoost model: 0.0008210242015147392
# RMSE score for polynimial regression: 0.005867663762123875
# RMSE score for CatBoost model: 0.011301488462533735

# %% [markdown]
# Visualize the result metrics

# %%
def plot_true_vs_pred(y_pred, y_test, title_text, ax=None, **kwargs):
    ax = ax or plt.gca()

    ax.set_title(title_text, y=1.01, fontsize=19, fontweight='bold')
    sns.scatterplot(x = y_pred, y = y_test, ax=ax, color='red', s=100)
    ax.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), color='black', linestyle='dashed')
    
    rmse = sqrt(mean_squared_error(y_test, y_pred))
    ax.text(0.17, 0.8, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')
    ax.set_ylabel('$Damage_{true}$', fontsize = 15)
    ax.set_xlabel('$Damage_{pred}$', fontsize = 15)
    ax.grid()

# %%
def plot_true_minus_pred(y_pred, y_test, title_text, ax=None, **kwargs):
    ax = ax or plt.gca()
    
    ax.set_title(title_text, y=1.01, fontsize = 20, fontweight='bold')
    sns.distplot((y_test - y_pred), kde=True, norm_hist=True, color='red')

    rmse = sqrt(mean_squared_error(y_test, y_pred))
    ax.text(-0.015, 1350, f'$RMSE={round(rmse, 4)}$', fontsize=12, fontweight='bold')

    ax.set_ylabel('$Occurence$', fontsize = 15)
    ax.set_xlabel('$Damage_{true}$ - $Damage_{pred}$', fontsize = 15)
    ax.grid()

# %%
plt.figure(figsize = (5, 5))
plot_true_vs_pred(y_pred_test, y_test, "Stacked model")

# %%
plt.figure(figsize = (5, 5))
plot_true_minus_pred(y_pred_test, y_test, 'Stacked model')

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

axes = axes.flatten()

# plot_true_vs_pred(y_pred_test, y_test, 'Stacked model', ax=axes[0])

plot_true_vs_pred(test_pred0.values.flatten(), y_test, 'LightGBM model', ax=axes[0])
plot_true_vs_pred(test_pred1.values.flatten(), y_test, 'AdaBoost model', ax=axes[1])
plot_true_vs_pred(test_pred2.values.flatten(), y_test, 'Polynom_reg model', ax=axes[2])
plot_true_vs_pred(test_pred3.values.flatten(), y_test, 'CatBoost model', ax=axes[3])
    
fig.tight_layout()
fig.show()

# %% [markdown]
# ## How to re-use the pre-trained model

# %%
# Import the new dataset
data = pd.read_csv('Data_training.csv', index_col = 0)
data.columns = ['Tg', 'Tk', 'n', 'damage']

# Define group variable
split_val = 0.1
data['groups'] = [1 if f > split_val else 0 for f in data.damage]

# Normalize the data
scaler = pickle.load(open('scaler.pkl', 'rb'))
data_scaled = scaler.transform(data)
data_scaled = pd.DataFrame(data_scaled, columns = data.columns)

# Make inference
x = data_scaled.loc[:, ['Tg', 'Tk', 'n']]
y_true = data['damage']

model1 = pickle.load(open('lightgbm_model.pkl', 'rb'))
model2 = pickle.load(open('polynom_reg_model.pkl', 'rb'))
model3 = pickle.load(open('catboost_model.pkl', 'rb'))
strong_model = pickle.load(open('xgbr_strong_model.pkl', 'rb'))

model1_preds = model1.predict(x)
model2_preds = model2.predict(x)
model3_preds = model3.predict(x)

models_preds = pd.concat([model1_preds, model2_preds, model3_preds], axis = 1)

y_pred = strong_model.predict(models_preds)
print(f"RMSE score for stacked model: {sqrt(mean_squared_error(y_pred, y_true))}")

# %% [markdown]
# For example

# %%
# Import the new data_interset
data_inter = pd.read_csv('/home/mraevsky/Skoltech/Surrogate_modeling/ciam_ml_model/Data_training_2.csv', index_col = 0)
data_inter.columns = ['Tg', 'Tk', 'n', 'damage']

# Define pseudo_group column
split_val = 0.1
data_inter['groups'] = [1 if f > split_val else 0 for f in data_inter.damage]

# Normalize the data_inter
scaler = pickle.load(open('../ciam_ml_model/scaler.pkl', 'rb'))
data_inter_scaled = scaler.transform(data_inter)
data_inter_scaled = pd.DataFrame(data_inter_scaled, columns = data_inter.columns)

# Make inference
x = data_inter_scaled.loc[:, ['Tg', 'Tk', 'n']]

model1 = pickle.load(open('../ciam_ml_model/lightgbm_model.pkl', 'rb'))
model2 = pickle.load(open('../ciam_ml_model/adaboost_model.pkl', 'rb'))
model3 = pickle.load(open('../ciam_ml_model/polynom_reg_model.pkl', 'rb'))
model4 = pickle.load(open('../ciam_ml_model/catboost_model.pkl', 'rb'))
strong_model = pickle.load(open('../ciam_ml_model/xgbr_strong_model.pkl', 'rb'))

model1_preds = model1.predict(x)
model2_preds = model2.predict(x)
model3_preds = model3.predict(x)
model4_preds = model4.predict(x)

models_preds = pd.concat([pd.DataFrame(model1_preds), 
                          pd.DataFrame(model2_preds), 
                          pd.DataFrame(model3_preds), 
                          pd.DataFrame(model4_preds)], axis = 1)
models_preds.columns = ['lightgbm_model', 'adaboost', 'polynom_reg', 'catboost']

y_pred = strong_model.predict(models_preds)

# Rescale data back to original scale
data_inter_pred = data_inter_scaled.loc[:, ['Tg', 'Tk', 'n']]
data_inter_pred['damage_pred'] = y_pred
data_inter_pred['groups'] = 0 # pseudo values
data_inter_pred = scaler.inverse_transform(data_inter_pred)
data_inter_pred
